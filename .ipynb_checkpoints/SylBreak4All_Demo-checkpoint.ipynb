# %% [markdown]
# # sylbreak4All (Version 0.90) Demo Running
# ### by Ye Kyaw Thu (Lab Leader, Language Understanding Lab, AI Mario, Myanmar)
# ### Date: 12 Sept 2026

# %%
# %pwd
# Out:
# '/mnt/disk1/ye/exp/sylbreak4all-0.9.0'

# %% [markdown]
# ## Small Corpus Info

# %%
# !wc examples/corpus/*.txt
# Out:
#   10   10  724 examples/corpus/bamar_burmese.txt
#   10   23 1040 examples/corpus/beik.txt
#   10   10  964 examples/corpus/dawei.txt
#   10   10  868 examples/corpus/mon.txt
#   10   10  934 examples/corpus/pao.txt
#   10   10  961 examples/corpus/po_kayin.txt
#   10   10 1051 examples/corpus/rakhine.txt
#   10   10  721 examples/corpus/sgaw_kayin.txt
#   10   10 1015 examples/corpus/shan.txt
#   90  103 8278 total

# %%
# !cat examples/corpus/bamar_burmese.txt
# Out:
# ကခဂဃင၀၁၂၃၄၅၆၇၈၉
# နေကောင်းလား။
# ကျန်းမာတယ်၊ဒါပေမဲ့အလုပ်များတယ်။
# မင်္ဂလာပါဆရာမ။
# တက္ကသိုလ်အသွားအပြန်ကိုသင်္ဘောစီးပြီးသွားရတယ်။
# ပုပ္ပါးတောင်ကိုထပ်တက်ချင်သေးတယ်။
# ကျောင်းသားကျောင်းသွားပါ။
# ကလေးကအိမ်မှာပါ
# ကျောင်းသားကျောင်းသူကျောင်းမှာ
# ပါပါသမီးကိုလွမ်းနေတယ်။

# %%
# !cat examples/corpus/beik.txt
# Out:
# နင်ဘာစီစဉ်နေရယ်ဆိုတာငါ့ဝိုပြောသင့်ပေါ့လန်း။
# သူလို့စာအုပ်သုံးထောင်ကျော်ရောင်းပီးဟောဘီ။
# ငယ်ငယ်တည်းကမင်းသားလုပ်ဝို့ဝါသနာပါစ။
# သူ တစ် ချိန် လုံး လုပ် နေ ဇာ ဂ ညဉ်း ပဲ့ ညည်း နေ ဇာ ။
# ဒယ်ကောင်မငယ်နင့်ဝိုဂရုစိုက်ရယ်လား။
# ဘဇာလောက်မြင့်မြတ်ရိ။
# နင်ဒယ်မှာအလုပ်လုပ်ဝယ်။
# ဒယ်ကောင်မငယ်ဟမင်းဟက်သဘောတူမှာမဟုတ်ဝ။
# နင့်ရဲ့သွားနှစ်ချောင်းကိုနုတ်ပစ်ရမရ်။
# သူ့ဆီကိုနင်ဖုန်းဆက်မယ်မဟုတ်ဝလား။

# %%
# !cat examples/corpus/dawei.txt
# Out:
# နန်ဟှဲဇာစီစဉ်နေဟှယ်ဆိုတာငါ့ကိုပြောသင့်ဟှယ်။
# သူးနို့စာအုပ်သုံးထော်ကျော်ရောပီးပီ။
# ချို့လူလေဟှာမွီးရာပါဇာတ်မှန်းသားလေမား။
# ချို့လူလေဟှာမွီးရာပါပွဲမှန်းသားလေပဲ့။
# သူနန့်ဟှိုဂရုစိုက်ပဲ့လား။
# ဟှယ်လော့မြတ်ဟှယ်။
# နန်အဲ့မာလောက်လောက်ဟှယ်။
# ဝယ်ရားကနန့်နဲ့ဘောတူမှာမှုဝ။
# နန့်သွားနှေ့ရှောဟှိုနှုပစ်ရမယ်။
# အဲဝယ်ဟှားနားဟှိုနန်ဖောင်းဆစ်ဟှို့မှုဟှလား။

# %%
# !cat examples/corpus/mon.txt
# Out:
# ၂၀မိဏေတ်ပၠန်တှ်ေဘာရပ်ဏောၚ်။
# ဗှ်ေဟယျတုဲမာန်ဟာ။
# ယဝ်ဗှ်ေဟွံပယှုက်အဲရတှ်ေတုဲမာန်ဏောၚ်။
# အဲဟယျဗှ်ေတိၚ်ဂီတာလေပ်မံၚ်။
# လၟုဟ်အဲဗ္တောန်တိၚ်မံၚ်ဂီတာ။
# ပေါဲဂီတဂှ်ဂိတုဂတမှကၠောန်ဏောၚ်။
# သွက်အဲဂွံအံၚ်ဇၞးရာဒနာကဵုညိ။
# ခိုဟ်ယျဆက်ဂစာန်ညိပၠန်။
# ဂလာန်ဗှ်ေပတိုန်လဝ်နူဏေအ်ဗ္တံဂှ်ခိုဟ်ကွေံကွေံ။
# ၜိုတ်အဲကၠောန်မာန်အဲဂစာန်လဝ်ရ။

# %%
# !cat examples/corpus/pao.txt
# Out:
# လိုမူႏပေႏမာꩻတမုဲင်ꩻဟောင်း
# ဝွေꩻသီးအီးကွီႏသညင်ꩻနာꩻတမွေးတဝ်း
# နီတယူႏလတဝ်းခင်ႏလမ်းနဝ်ꩻ
# နာꩻပါꩻမုဲင်ꩻမန်နေဂျာဟောင်း
# ဝွေꩻမူႏခြောဝ်ငဝ်း
# နာꩻနမ်းတွမ်ႏနာꩻနမ်းယွုမ်းအံႏမုꩻမဉ်အဝ်ႏတဲ့ကျိုꩻစာꩻစံဟုဲင်း
# ချာနေနမ်းမဉ်ဟောင်း
# ဝွေꩻမူႏတွမ်ႏဝွေꩻထေင်ညင်ချာငါꩻဝင်ꩻဟောင်း
# နာꩻနဝ်ꩻလိုလွစ်ဟောင်း
# အရီးသွတ်တဗာႏအနေႏဝွေꩻမူႏအဝ်ႏလိုႏဖျင်ꩻဆင်ꩻဒဲဉ်ꩻရဝ်ꩻတာႏ

# %%
# !cat examples/corpus/po_kayin.txt
# Out:
# နဂဲၫထဲၩ့မၩဆၧလဖၪအဂးနနီၪ့ယါလၩ့နၥၭအ့ၬဧၪ
# ယခိၭနၧၩလၧယကကိၭဖံၭၥိၭနၧၩအဂးလီၫ
# မနီၪလဲၪဂၭဂီၩ့လဲၪနီၪနၥ့ၪယၫဧၪ
# ယၥၭလမုၬဘၪလၧနထံၩၥိၭအဂးနီၪလီၩအ့ၪဆံၭ
# ကဘၪအၪ့လံၩ့တၨၭဒူၭဧၪလမွဲဘၪကဘၪဎွ့ၩခွံၬဧၪနီၪယၥ့ၪယၫအ့ၬ
# ထိၪၥံၪယူၩလီၫ
# ဆၧအမွဲလၥၨၩလၩ့ထံးလၥၨၩ
# ဂဲၫထဲၩ့ဎွ့ၩန့ဘိၩလၧမုဂၪနံၩအိၩလၧဆၧအၪမံၩ့ဆဲၫ့ဖၭဒိၪနီၪလီၫ
# ဘိၩ့နဲၪ့ယီၩနီၪအဝ့ၫအီၪကၠၧၫ့ကၠၧၫ့လၧအမိအဖါၥံၪလီၫ
# နကယိၦမုၪနီၪဧၪ

# %%
# !cat examples/corpus/rakhine.txt
# Out:
# မင်းယင်းချင့်ကိုအခြားတစ်ခုနန့်မချိတ်ပါလား။
# ထိုမချေတစ်ယောက်လေ့မမှတ်မိပါယာ။
# ယင်းချင့်ကျွန်တော်ရို့အတွက်ခက်ခရေ။
# မင်းပြောခရေပိုင်ကျွန်တော်ယှင်းပြခရေ။
# သူ့ကိုထိန်းဖို့မင်းရာတတ်နိုင်ရေ။
# ယင်းချင့်ကိုငါတက်နင်းမိလားလာ။
# ငါစဉ်းစားရေပိုင်စဉ်းစားပါ။
# အတင်းပြောရစွာမုန်းရေ။
# ​နောက်ဆုံးတစ်ကြိမ်သူ့ကိုချစ်ပါရေလို့ပြောခွင့်တောင်မရပါ။
# နာဆာမှဒုံးပျံစတက်စွာနန့်သူမှတ်တမ်းရွီးခရေ။

# %%
# !cat examples/corpus/sgaw_kayin.txt
# Out:
# နဘၣ်သံကွၢ်တၢ်မတၤန့ၣ်လဲၣ်
# တၢ်ဂ့ၢ်ဝဲအံၤနဘၣ်တဲတၢ်မတၤန့ၣ်လဲၣ်
# နဘၣ်ထံၣ်လိာ်သးဒီးမတၤန့ၣ်လဲၣ်
# နဘၣ်တၢ်ဃုထၢမတၤန့ၣ်လဲၣ်
# နဘၣ်စံၣ်ညီၣ်တၢ်မတၤန့ၣ်လဲၣ်
# နဘၣ်ကွၢ်ဃုတၢ်မတၤန့ၣ်လဲၣ်
# နတဲတ့ၢ်မတၤန့ၣ်လဲၣ်
# နဟ့ၣ်တ့ၢ်မတၤန့ၣ်လဲၣ်
# နကိးတ့ၢ်မတၤန့ၣ်လဲၣ်
# နထံၣ်တ့ၢ်မတၤသ့ၣ်န့ၣ်လဲၣ်

# %%
# !cat examples/corpus/shan.txt
# Out:
# ယွင်ႈၵုင်ႇၵူၼ်းႁတ်းႁၢၼ်ႁႃႉ
# ဢၼ်ၸႅတ်ႈတူၺ်းသူႁေႃႈၵႃးၼႆႉတွပ်ႇယဝ်ႉယဝ်ႉႁႃႉ
# လွင်ႈၶူင်သၢင်ႈမႂ်းဢမ်ႇႁိုင်သင်တေဢွင်ႇမၢၼ်ယဝ်ႉ
# ဢၼ်ၼၼ်ႉပဵၼ်လွင်ႈၵိတ်ႇၶွင်ႈသူ
# တေၵိၼ်သေဢၼ်ဢၼ်ႁႃႉ
# ဢွမ်မူင်းၵဝ်ႁႃဢမ်ႇႁၼ်
# ပဵၼ်ၵူၼ်းဢၼ်လဵၼ်ႈၸိူင်းၶႅၼ်ႇတႄႉယဝ်ႈ
# ၵုပ်ႉၵူႈသူၼႆႉတႄႇၽုၺ်ႇသႅင်ႇၵိၼ်ယမ်ႉၼႆႉမႃးတေႃႇမိူဝ်ႈလဵဝ်ဢၼ်ၽႅဝ်မႃးၼႆႉပဵၼ်႙႙႙ၵူႈယဝ်ႉ
# ၼင်ႈႁွင်ႈတၢင်းၼႃႈဢဝ်ၼႄႈ
# လႆႈႁႅင်းလီၵႃႈႁိုဝ်

# %% [markdown]
# ## Perl

# %%
# !perl perl/sylbreak4all.pl --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !perl perl/sylbreak4all.pl -i examples/corpus/bamar_burmese.txt -l bm
# Out:
# |က|ခ|ဂ|ဃ|င|၀|၁|၂|၃|၄|၅|၆|၇|၈|၉
# |နေ|ကောင်း|လား|။
# |ကျန်း|မာ|တယ်|၊|ဒါ|ပေ|မဲ့|အ|လုပ်|များ|တယ်|။
# |မင်္ဂ|လာ|ပါ|ဆ|ရာ|မ|။
# |တက္က|သိုလ်|အ|သွား|အ|ပြန်|ကို|သင်္ဘော|စီး|ပြီး|သွား|ရ|တယ်|။
# |ပုပ္ပါး|တောင်|ကို|ထပ်|တက်|ချင်|သေး|တယ်|။
# |ကျောင်း|သား|ကျောင်း|သွား|ပါ|။
# |က|လေး|က|အိမ်|မှာ|ပါ
# |ကျောင်း|သား|ကျောင်း|သူ|ကျောင်း|မှာ
# |ပါ|ပါ|သ|မီး|ကို|လွမ်း|နေ|တယ်|။

# %%
# !perl perl/sylbreak4all.pl -i examples/corpus/beik.txt -l bk -s "/"
# Out:
# /နင်/ဘာ/စီ/စဉ်/နေ/ရယ်/ဆို/တာ/ငါ့/ဝို/ပြော/သင့်/ပေါ့/လန်း/။
# /သူ/လို့/စာ/အုပ်/သုံး/ထောင်/ကျော်/ရောင်း/ပီး/ဟော/ဘီ/။
# /ငယ်/ငယ်/တည်း/က/မင်း/သား/လုပ်/ဝို့/ဝါ/သ/နာ/ပါ/စ/။
# /သူ/တစ်/ချိန်/လုံး/လုပ်/နေ/ဇာ/ဂ/ညဉ်း/ပဲ့/ညည်း/နေ/ဇာ/။
# /ဒယ်/ကောင်/မ/ငယ်/နင့်/ဝို/ဂ/ရု/စိုက်/ရယ်/လား/။
# /ဘ/ဇာ/လောက်/မြင့်/မြတ်/ရိ/။
# /နင်/ဒယ်/မှာ/အ/လုပ်/လုပ်/ဝယ်/။
# /ဒယ်/ကောင်/မ/ငယ်/ဟ/မင်း/ဟက်/သ/ဘော/တူ/မှာ/မ/ဟုတ်/ဝ/။
# /နင့်/ရဲ့/သွား/နှစ်/ချောင်း/ကို/နုတ်/ပစ်/ရ/မရ်/။
# /သူ့/ဆီ/ကို/နင်/ဖုန်း/ဆက်/မယ်/မ/ဟုတ်/ဝ/လား/။

# %%
# !perl perl/sylbreak4all.pl -i examples/corpus/sgaw_kayin.txt -l sk -s " "
# Out:
# န ဘၣ် သံ ကွၢ် တၢ် မ တၤ န့ၣ် လဲၣ်
# တၢ် ဂ့ၢ် ဝဲ အံၤ န ဘၣ် တဲ တၢ် မ တၤ န့ၣ် လဲၣ်
# န ဘၣ် ထံၣ် လိာ် သး ဒီး မ တၤ န့ၣ် လဲၣ်
# န ဘၣ် တၢ် ဃု ထၢ မ တၤ န့ၣ် လဲၣ်
# န ဘၣ် စံၣ် ညီၣ် တၢ် မ တၤ န့ၣ် လဲၣ်
# န ဘၣ် ကွၢ် ဃု တၢ် မ တၤ န့ၣ် လဲၣ်
# န တဲ တ့ၢ် မ တၤ န့ၣ် လဲၣ်
# န ဟ့ၣ် တ့ၢ် မ တၤ န့ၣ် လဲၣ်
# န ကိး တ့ၢ် မ တၤ န့ၣ် လဲၣ်
# န ထံၣ် တ့ၢ် မ တၤ သ့ၣ် န့ၣ် လဲၣ်

# %% [markdown]
# ## Python

# %%
# !python python/sylbreak4all.py --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !python3 python/sylbreak4all.py -i examples/corpus/shan.txt -l sh
# Out:
# |ယွင်ႈ|ၵုင်ႇ|ၵူၼ်း|ႁတ်း|ႁၢၼ်|ႁႃႉ
# |ဢၼ်|ၸႅတ်ႈ|တူၺ်း|သူ|ႁေႃႈ|ၵႃး|ၼႆႉ|တွပ်ႇ|ယဝ်ႉ|ယဝ်ႉ|ႁႃႉ
# |လွင်ႈ|ၶူင်|သၢင်ႈ|မႂ်း|ဢမ်ႇ|ႁိုင်|သင်|တေ|ဢွင်ႇ|မၢၼ်|ယဝ်ႉ
# |ဢၼ်|ၼၼ်ႉ|ပဵၼ်|လွင်ႈ|ၵိတ်ႇ|ၶွင်ႈ|သူ
# |တေ|ၵိၼ်|သေ|ဢၼ်|ဢၼ်|ႁႃႉ
# |ဢွမ်|မူင်း|ၵဝ်|ႁႃ|ဢမ်ႇ|ႁၼ်
# |ပဵၼ်|ၵူၼ်း|ဢၼ်|လဵၼ်ႈ|ၸိူင်း|ၶႅၼ်ႇ|တႄႉ|ယဝ်ႈ
# |ၵုပ်ႉ|ၵူႈ|သူ|ၼႆႉ|တႄႇ|ၽုၺ်ႇ|သႅင်ႇ|ၵိၼ်|ယမ်ႉ|ၼႆႉ|မႃး|တေႃႇ|မိူဝ်ႈ|လဵဝ်|ဢၼ်|ၽႅဝ်|မႃး|ၼႆႉ|ပဵၼ်|႙|႙|႙|ၵူႈ|ယဝ်ႉ
# |ၼင်ႈ|ႁွင်ႈ|တၢင်း|ၼႃႈ|ဢဝ်|ၼႄႈ
# |လႆႈ|ႁႅင်း|လီ|ၵႃႈ|ႁိုဝ်

# %%
# !python3 python/sylbreak4all.py -i examples/corpus/pao.txt -l po -s "/"
# Out:
# /လို/မူႏ/ပေႏ/မာꩻ/တ/မုဲင်ꩻ/ဟောင်း
# /ဝွေꩻ/သီး/အီး/ကွီႏ/သ/ညင်ꩻ/နာꩻ/တ/မွေး/တဝ်း
# /နီ/တ/ယူႏ/လ/တဝ်း/ခင်ႏ/လမ်း/နဝ်ꩻ
# /နာꩻ/ပါꩻ/မုဲင်ꩻ/မန်/နေ/ဂျာ/ဟောင်း
# /ဝွေꩻ/မူႏ/ခြောဝ်/ငဝ်း
# /နာꩻ/နမ်း/တွမ်ႏ/နာꩻ/နမ်း/ယွုမ်း/အံႏ/မုꩻ/မဉ်/အဝ်ႏ/တဲ့/ကျိုꩻ/စာꩻ/စံ/ဟုဲင်း
# /ချာ/နေ/နမ်း/မဉ်/ဟောင်း
# /ဝွေꩻ/မူႏ/တွမ်ႏ/ဝွေꩻ/ထေင်/ညင်/ချာ/ငါꩻ/ဝင်ꩻ/ဟောင်း
# /နာꩻ/နဝ်ꩻ/လို/လွစ်/ဟောင်း
# /အ/ရီး/သွတ်/တ/ဗာႏ/အ/နေႏ/ဝွေꩻ/မူႏ/အဝ်ႏ/လိုႏ/ဖျင်ꩻ/ဆင်ꩻ/ဒဲဉ်ꩻ/ရဝ်ꩻ/တာႏ

# %%
# !python3 python/sylbreak4all.py -i examples/corpus/dawei.txt -l dw
# Out:
# |နန်|ဟှဲ|ဇာ|စီ|စဉ်|နေ|ဟှယ်|ဆို|တာ|ငါ့|ကို|ပြော|သင့်|ဟှယ်|။
# |သူး|နို့|စာ|အုပ်|သုံး|ထော်|ကျော်|ရော|ပီး|ပီ|။
# |ချို့|လူ|လေ|ဟှာ|မွီး|ရာ|ပါ|ဇာတ်|မှန်း|သား|လေ|မား|။
# |ချို့|လူ|လေ|ဟှာ|မွီး|ရာ|ပါ|ပွဲ|မှန်း|သား|လေ|ပဲ့|။
# |သူ|နန့်|ဟှို|ဂ|ရု|စိုက်|ပဲ့|လား|။
# |ဟှယ်|လော့|မြတ်|ဟှယ်|။
# |နန်|အဲ့|မာ|လောက်|လောက်|ဟှယ်|။
# |ဝယ်|ရား|က|နန့်|နဲ့|ဘော|တူ|မှာ|မှု|ဝ|။
# |နန့်|သွား|နှေ့|ရှော|ဟှို|နှု|ပစ်|ရ|မယ်|။
# |အဲ|ဝယ်|ဟှား|နား|ဟှို|နန်|ဖောင်း|ဆစ်|ဟှို့|မှု|ဟှ|လား|။

# %% [markdown]
# ## PHP

# %%
# !php php/sylbreak4all.php --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !php php/sylbreak4all.php -i examples/corpus/mon.txt -l mo
# Out:
# |၂|၀|မိ|ဏေတ်|ပၠန်|တှ်ေ|ဘာ|ရပ်|ဏောၚ်|။
# |ဗှ်ေ|ဟ|ယျ|တုဲ|မာန်|ဟာ|။
# |ယဝ်|ဗှ်ေ|ဟွံ|ပ|ယှုက်|အဲ|ရ|တှ်ေ|တုဲ|မာန်|ဏောၚ်|။
# |အဲ|ဟ|ယျ|ဗှ်ေ|တိၚ်|ဂီ|တာ|လေပ်|မံၚ်|။
# |လၟုဟ်|အဲဗ္တောန်|တိၚ်|မံၚ်|ဂီ|တာ|။
# |ပေါဲ|ဂီ|တ|ဂှ်|ဂိ|တု|ဂ|တ|မှ|ကၠောန်|ဏောၚ်|။
# |သွက်|အဲ|ဂွံ|အံၚ်|ဇၞး|ရာ|ဒ|နာ|ကဵု|ညိ|။
# |ခိုဟ်|ယျ|ဆက်|ဂ|စာန်|ညိ|ပၠန်|။
# |ဂ|လာန်|ဗှ်ေ|ပ|တိုန်|လဝ်|နူ|ဏေအ်ဗ္တံ|ဂှ်|ခိုဟ်|ကွေံ|ကွေံ|။
# |ၜိုတ်|အဲ|ကၠောန်|မာန်|အဲ|ဂ|စာန်|လဝ်|ရ|။

# %%
# !php php/sylbreak4all.php -i examples/corpus/po_kayin.txt -l pk
# Out:
# |န|ဂဲၫ|ထဲၩ့|မၩ|ဆၧ|လ|ဖၪ|အ|ဂး|န|နီၪ့|ယါ|လၩ့|န|ၥၭ|အ့ၬ|ဧၪ
# |ယ|ခိၭ|နၧၩ|လၧ|ယ|က|ကိၭ|ဖံၭ|ၥိၭ|နၧၩ|အ|ဂး|လီၫ
# |မ|နီၪ|လဲၪ|ဂၭ|ဂီၩ့|လဲၪ|နီၪ|န|ၥ့ၪ|ယၫ|ဧၪ
# |ယ|ၥၭ|လ|မုၬ|ဘၪ|လၧ|န|ထံၩ|ၥိၭ|အ|ဂး|နီၪ|လီၩ|အ့ၪ|ဆံၭ
# |က|ဘၪ|အၪ့|လံၩ့|တၨၭ|ဒူၭ|ဧၪ|လ|မွဲ|ဘၪ|က|ဘၪ|ဎွ့ၩ|ခွံၬ|ဧၪ|နီၪ|ယ|ၥ့ၪ|ယၫ|အ့ၬ
# |ထိၪ|ၥံၪ|ယူၩ|လီၫ
# |ဆၧ|အ|မွဲ|လ|ၥၨၩ|လၩ့|ထံး|လ|ၥၨၩ
# |ဂဲၫ|ထဲၩ့|ဎွ့ၩ|န့|ဘိၩ|လၧ|မု|ဂၪ|နံၩ|အိၩ|လၧ|ဆၧ|အၪ|မံၩ့|ဆဲၫ့|ဖၭ|ဒိၪ|နီၪ|လီၫ
# |ဘိၩ့|နဲၪ့|ယီၩ|နီၪ|အ|ဝ့ၫ|အီၪ|ကၠၧၫ့|ကၠၧၫ့|လၧ|အ|မိ|အ|ဖါ|ၥံၪ|လီၫ
# |န|က|ယိ|ၦ|မုၪ|နီၪ|ဧၪ

# %%
# !php php/sylbreak4all.php -i examples/corpus/rakhine.txt -l rk -s "_"
# Out:
# _မင်း_ယင်း_ချင့်_ကို_အ_ခြား_တစ်_ခု_နန့်_မ_ချိတ်_ပါ_လား_။
# _ထို_မ_ချေ_တစ်_ယောက်_လေ့_မ_မှတ်_မိ_ပါ_ယာ_။
# _ယင်း_ချင့်_ကျွန်_တော်_ရို့_အ_တွက်_ခက်_ခ_ရေ_။
# _မင်း_ပြော_ခ_ရေ_ပိုင်_ကျွန်_တော်_ယှင်း_ပြ_ခ_ရေ_။
# _သူ့_ကို_ထိန်း_ဖို့_မင်း_ရာ_တတ်_နိုင်_ရေ_။
# _ယင်း_ချင့်_ကို_ငါ_တက်_နင်း_မိ_လား_လာ_။
# _ငါ_စဉ်း_စား_ရေ_ပိုင်_စဉ်း_စား_ပါ_။
# _အ_တင်း_ပြော_ရ_စွာ_မုန်း_ရေ_။
# ​_နောက်_ဆုံး_တစ်_ကြိမ်_သူ့_ကို_ချစ်_ပါ_ရေ_လို့_ပြော_ခွင့်_တောင်_မ_ရ_ပါ_။
# _နာ_ဆာ_မှ_ဒုံး_ပျံ_စ_တက်_စွာ_နန့်_သူ_မှတ်_တမ်း_ရွီး_ခ_ရေ_။

# %% [markdown]
# ## Java

# %%
# %cd java
# Out:
# /mnt/disk1/ye/exp/sylbreak4all-0.9.0/java

# %%
# !ls
# Out:
# compile.sh  run_java.sh  sylbreak4all.java

# %%
# !./compile.sh

# %%
# !ls
# Out:
#  compile.sh   'sylbreak4all$MatcherCompat.class'   sylbreak4all.java
#  run_java.sh   sylbreak4all.class

# %%
# !cat run_java.sh
# Out:
# #!/bin/sh
# set -eu
# SCRIPT_DIR=$(CDPATH= cd -- "$(dirname -- "$0")" && pwd)
# java -cp "$SCRIPT_DIR" sylbreak4all "$@"

# %%
# !./run_java.sh --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !./run_java.sh -i ../examples/corpus/pao.txt -l po
# Out:
# |လို|မူႏ|ပေႏ|မာꩻ|တ|မုဲင်ꩻ|ဟောင်း
# |ဝွေꩻ|သီး|အီး|ကွီႏ|သ|ညင်ꩻ|နာꩻ|တ|မွေး|တဝ်း
# |နီ|တ|ယူႏ|လ|တဝ်း|ခင်ႏ|လမ်း|နဝ်ꩻ
# |နာꩻ|ပါꩻ|မုဲင်ꩻ|မန်|နေ|ဂျာ|ဟောင်း
# |ဝွေꩻ|မူႏ|ခြောဝ်|ငဝ်း
# |နာꩻ|နမ်း|တွမ်ႏ|နာꩻ|နမ်း|ယွုမ်း|အံႏ|မုꩻ|မဉ်|အဝ်ႏ|တဲ့|ကျိုꩻ|စာꩻ|စံ|ဟုဲင်း
# |ချာ|နေ|နမ်း|မဉ်|ဟောင်း
# |ဝွေꩻ|မူႏ|တွမ်ႏ|ဝွေꩻ|ထေင်|ညင်|ချာ|ငါꩻ|ဝင်ꩻ|ဟောင်း
# |နာꩻ|နဝ်ꩻ|လို|လွစ်|ဟောင်း
# |အ|ရီး|သွတ်|တ|ဗာႏ|အ|နေႏ|ဝွေꩻ|မူႏ|အဝ်ႏ|လိုႏ|ဖျင်ꩻ|ဆင်ꩻ|ဒဲဉ်ꩻ|ရဝ်ꩻ|တာႏ

# %%
# !./run_java.sh -i ../examples/corpus/rakhine.txt -l rk -s " "
# Out:
# မင်း ယင်း ချင့် ကို အ ခြား တစ် ခု နန့် မ ချိတ် ပါ လား ။
# ထို မ ချေ တစ် ယောက် လေ့ မ မှတ် မိ ပါ ယာ ။
# ယင်း ချင့် ကျွန် တော် ရို့ အ တွက် ခက် ခ ရေ ။
# မင်း ပြော ခ ရေ ပိုင် ကျွန် တော် ယှင်း ပြ ခ ရေ ။
# သူ့ ကို ထိန်း ဖို့ မင်း ရာ တတ် နိုင် ရေ ။
# ယင်း ချင့် ကို ငါ တက် နင်း မိ လား လာ ။
# ငါ စဉ်း စား ရေ ပိုင် စဉ်း စား ပါ ။
# အ တင်း ပြော ရ စွာ မုန်း ရေ ။
# ​ နောက် ဆုံး တစ် ကြိမ် သူ့ ကို ချစ် ပါ ရေ လို့ ပြော ခွင့် တောင် မ ရ ပါ ။
# နာ ဆာ မှ ဒုံး ပျံ စ တက် စွာ နန့် သူ မှတ် တမ်း ရွီး ခ ရေ ။

# %%
# !./run_java.sh -i ../examples/corpus/shan.txt -l sh -s " "
# Out:
# ယွင်ႈ ၵုင်ႇ ၵူၼ်း ႁတ်း ႁၢၼ် ႁႃႉ
# ဢၼ် ၸႅတ်ႈ တူၺ်း သူ ႁေႃႈ ၵႃး ၼႆႉ တွပ်ႇ ယဝ်ႉ ယဝ်ႉ ႁႃႉ
# လွင်ႈ ၶူင် သၢင်ႈ မႂ်း ဢမ်ႇ ႁိုင် သင် တေ ဢွင်ႇ မၢၼ် ယဝ်ႉ
# ဢၼ် ၼၼ်ႉ ပဵၼ် လွင်ႈ ၵိတ်ႇ ၶွင်ႈ သူ
# တေ ၵိၼ် သေ ဢၼ် ဢၼ် ႁႃႉ
# ဢွမ် မူင်း ၵဝ် ႁႃ ဢမ်ႇ ႁၼ်
# ပဵၼ် ၵူၼ်း ဢၼ် လဵၼ်ႈ ၸိူင်း ၶႅၼ်ႇ တႄႉ ယဝ်ႈ
# ၵုပ်ႉ ၵူႈ သူ ၼႆႉ တႄႇ ၽုၺ်ႇ သႅင်ႇ ၵိၼ် ယမ်ႉ ၼႆႉ မႃး တေႃႇ မိူဝ်ႈ လဵဝ် ဢၼ် ၽႅဝ် မႃး ၼႆႉ ပဵၼ် ႙ ႙ ႙ ၵူႈ ယဝ်ႉ
# ၼင်ႈ ႁွင်ႈ တၢင်း ၼႃႈ ဢဝ် ၼႄႈ
# လႆႈ ႁႅင်း လီ ၵႃႈ ႁိုဝ်

# %% [markdown]
# ## JavaScript / Node.js

# %%
# %cd /mnt/disk1/ye/exp/sylbreak4all-0.9.0
# Out:
# /mnt/disk1/ye/exp/sylbreak4all-0.9.0

# %%
# !node java_script/sylbreak4all.js --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !node java_script/sylbreak4all.js -i examples/corpus/rakhine.txt -l rk
# Out:
# |မင်း|ယင်း|ချင့်|ကို|အ|ခြား|တစ်|ခု|နန့်|မ|ချိတ်|ပါ|လား|။
# |ထို|မ|ချေ|တစ်|ယောက်|လေ့|မ|မှတ်|မိ|ပါ|ယာ|။
# |ယင်း|ချင့်|ကျွန်|တော်|ရို့|အ|တွက်|ခက်|ခ|ရေ|။
# |မင်း|ပြော|ခ|ရေ|ပိုင်|ကျွန်|တော်|ယှင်း|ပြ|ခ|ရေ|။
# |သူ့|ကို|ထိန်း|ဖို့|မင်း|ရာ|တတ်|နိုင်|ရေ|။
# |ယင်း|ချင့်|ကို|ငါ|တက်|နင်း|မိ|လား|လာ|။
# |ငါ|စဉ်း|စား|ရေ|ပိုင်|စဉ်း|စား|ပါ|။
# |အ|တင်း|ပြော|ရ|စွာ|မုန်း|ရေ|။
# ​|နောက်|ဆုံး|တစ်|ကြိမ်|သူ့|ကို|ချစ်|ပါ|ရေ|လို့|ပြော|ခွင့်|တောင်|မ|ရ|ပါ|။
# |နာ|ဆာ|မှ|ဒုံး|ပျံ|စ|တက်|စွာ|နန့်|သူ|မှတ်|တမ်း|ရွီး|ခ|ရေ|။

# %%
# !node java_script/sylbreak4all.js -i examples/corpus/beik.txt -l bk -s "/"
# Out:
# /နင်/ဘာ/စီ/စဉ်/နေ/ရယ်/ဆို/တာ/ငါ့/ဝို/ပြော/သင့်/ပေါ့/လန်း/။
# /သူ/လို့/စာ/အုပ်/သုံး/ထောင်/ကျော်/ရောင်း/ပီး/ဟော/ဘီ/။
# /ငယ်/ငယ်/တည်း/က/မင်း/သား/လုပ်/ဝို့/ဝါ/သ/နာ/ပါ/စ/။
# /သူ/တစ်/ချိန်/လုံး/လုပ်/နေ/ဇာ/ဂ/ညဉ်း/ပဲ့/ညည်း/နေ/ဇာ/။
# /ဒယ်/ကောင်/မ/ငယ်/နင့်/ဝို/ဂ/ရု/စိုက်/ရယ်/လား/။
# /ဘ/ဇာ/လောက်/မြင့်/မြတ်/ရိ/။
# /နင်/ဒယ်/မှာ/အ/လုပ်/လုပ်/ဝယ်/။
# /ဒယ်/ကောင်/မ/ငယ်/ဟ/မင်း/ဟက်/သ/ဘော/တူ/မှာ/မ/ဟုတ်/ဝ/။
# /နင့်/ရဲ့/သွား/နှစ်/ချောင်း/ကို/နုတ်/ပစ်/ရ/မရ်/။
# /သူ့/ဆီ/ကို/နင်/ဖုန်း/ဆက်/မယ်/မ/ဟုတ်/ဝ/လား/။

# %%
# !node java_script/sylbreak4all.js -i examples/corpus/bamar_burmese.txt -l bm
# Out:
# |က|ခ|ဂ|ဃ|င|၀|၁|၂|၃|၄|၅|၆|၇|၈|၉
# |နေ|ကောင်း|လား|။
# |ကျန်း|မာ|တယ်|၊|ဒါ|ပေ|မဲ့|အ|လုပ်|များ|တယ်|။
# |မင်္ဂ|လာ|ပါ|ဆ|ရာ|မ|။
# |တက္က|သိုလ်|အ|သွား|အ|ပြန်|ကို|သင်္ဘော|စီး|ပြီး|သွား|ရ|တယ်|။
# |ပုပ္ပါး|တောင်|ကို|ထပ်|တက်|ချင်|သေး|တယ်|။
# |ကျောင်း|သား|ကျောင်း|သွား|ပါ|။
# |က|လေး|က|အိမ်|မှာ|ပါ
# |ကျောင်း|သား|ကျောင်း|သူ|ကျောင်း|မှာ
# |ပါ|ပါ|သ|မီး|ကို|လွမ်း|နေ|တယ်|။

# %% [markdown]
# ## Ruby

# %%
# %cd /mnt/disk1/ye/exp/sylbreak4all-0.9.0
# Out:
# /mnt/disk1/ye/exp/sylbreak4all-0.9.0

# %%
# !ruby ruby/sylbreak4all.rb --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !ruby ruby/sylbreak4all.rb -i examples/corpus/sgaw_kayin.txt -l sk
# Out:
# |န|ဘၣ်|သံ|ကွၢ်|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |တၢ်|ဂ့ၢ်|ဝဲ|အံၤ|န|ဘၣ်|တဲ|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|ထံၣ်|လိာ်|သး|ဒီး|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|တၢ်|ဃု|ထၢ|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|စံၣ်|ညီၣ်|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|ကွၢ်|ဃု|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|တဲ|တ့ၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဟ့ၣ်|တ့ၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ကိး|တ့ၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ထံၣ်|တ့ၢ်|မ|တၤ|သ့ၣ်|န့ၣ်|လဲၣ်

# %%
# !ruby ruby/sylbreak4all.rb -i examples/corpus/mon.txt -l mo -s " "
# Out:
# ၂ ၀ မိ ဏေတ် ပၠန် တှ်ေ ဘာ ရပ် ဏောၚ် ။
# ဗှ်ေ ဟ ယျ တုဲ မာန် ဟာ ။
# ယဝ် ဗှ်ေ ဟွံ ပ ယှုက် အဲ ရ တှ်ေ တုဲ မာန် ဏောၚ် ။
# အဲ ဟ ယျ ဗှ်ေ တိၚ် ဂီ တာ လေပ် မံၚ် ။
# လၟုဟ် အဲဗ္တောန် တိၚ် မံၚ် ဂီ တာ ။
# ပေါဲ ဂီ တ ဂှ် ဂိ တု ဂ တ မှ ကၠောန် ဏောၚ် ။
# သွက် အဲ ဂွံ အံၚ် ဇၞး ရာ ဒ နာ ကဵု ညိ ။
# ခိုဟ် ယျ ဆက် ဂ စာန် ညိ ပၠန် ။
# ဂ လာန် ဗှ်ေ ပ တိုန် လဝ် နူ ဏေအ်ဗ္တံ ဂှ် ခိုဟ် ကွေံ ကွေံ ။
# ၜိုတ် အဲ ကၠောန် မာန် အဲ ဂ စာန် လဝ် ရ ။

# %%
# !ruby ruby/sylbreak4all.rb -i examples/corpus/shan.txt -l sh -s " "
# Out:
# ယွင်ႈ ၵုင်ႇ ၵူၼ်း ႁတ်း ႁၢၼ် ႁႃႉ
# ဢၼ် ၸႅတ်ႈ တူၺ်း သူ ႁေႃႈ ၵႃး ၼႆႉ တွပ်ႇ ယဝ်ႉ ယဝ်ႉ ႁႃႉ
# လွင်ႈ ၶူင် သၢင်ႈ မႂ်း ဢမ်ႇ ႁိုင် သင် တေ ဢွင်ႇ မၢၼ် ယဝ်ႉ
# ဢၼ် ၼၼ်ႉ ပဵၼ် လွင်ႈ ၵိတ်ႇ ၶွင်ႈ သူ
# တေ ၵိၼ် သေ ဢၼ် ဢၼ် ႁႃႉ
# ဢွမ် မူင်း ၵဝ် ႁႃ ဢမ်ႇ ႁၼ်
# ပဵၼ် ၵူၼ်း ဢၼ် လဵၼ်ႈ ၸိူင်း ၶႅၼ်ႇ တႄႉ ယဝ်ႈ
# ၵုပ်ႉ ၵူႈ သူ ၼႆႉ တႄႇ ၽုၺ်ႇ သႅင်ႇ ၵိၼ် ယမ်ႉ ၼႆႉ မႃး တေႃႇ မိူဝ်ႈ လဵဝ် ဢၼ် ၽႅဝ် မႃး ၼႆႉ ပဵၼ် ႙ ႙ ႙ ၵူႈ ယဝ်ႉ
# ၼင်ႈ ႁွင်ႈ တၢင်း ၼႃႈ ဢဝ် ၼႄႈ
# လႆႈ ႁႅင်း လီ ၵႃႈ ႁိုဝ်

# %% [markdown]
# ## Bash wrapper

# %%
# %pwd
# Out:
# '/mnt/disk1/ye/exp/sylbreak4all-0.9.0'

# %%
# !bash bash/sylbreak4all.sh --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !bash bash/sylbreak4all.sh -i examples/corpus/po_kayin.txt -l pk
# Out:
# |န|ဂဲၫ|ထဲၩ့|မၩ|ဆၧ|လ|ဖၪ|အ|ဂး|န|နီၪ့|ယါ|လၩ့|န|ၥၭ|အ့ၬ|ဧၪ
# |ယ|ခိၭ|နၧၩ|လၧ|ယ|က|ကိၭ|ဖံၭ|ၥိၭ|နၧၩ|အ|ဂး|လီၫ
# |မ|နီၪ|လဲၪ|ဂၭ|ဂီၩ့|လဲၪ|နီၪ|န|ၥ့ၪ|ယၫ|ဧၪ
# |ယ|ၥၭ|လ|မုၬ|ဘၪ|လၧ|န|ထံၩ|ၥိၭ|အ|ဂး|နီၪ|လီၩ|အ့ၪ|ဆံၭ
# |က|ဘၪ|အၪ့|လံၩ့|တၨၭ|ဒူၭ|ဧၪ|လ|မွဲ|ဘၪ|က|ဘၪ|ဎွ့ၩ|ခွံၬ|ဧၪ|နီၪ|ယ|ၥ့ၪ|ယၫ|အ့ၬ
# |ထိၪ|ၥံၪ|ယူၩ|လီၫ
# |ဆၧ|အ|မွဲ|လ|ၥၨၩ|လၩ့|ထံး|လ|ၥၨၩ
# |ဂဲၫ|ထဲၩ့|ဎွ့ၩ|န့|ဘိၩ|လၧ|မု|ဂၪ|နံၩ|အိၩ|လၧ|ဆၧ|အၪ|မံၩ့|ဆဲၫ့|ဖၭ|ဒိၪ|နီၪ|လီၫ
# |ဘိၩ့|နဲၪ့|ယီၩ|နီၪ|အ|ဝ့ၫ|အီၪ|ကၠၧၫ့|ကၠၧၫ့|လၧ|အ|မိ|အ|ဖါ|ၥံၪ|လီၫ
# |န|က|ယိ|ၦ|မုၪ|နီၪ|ဧၪ

# %%
# !bash bash/sylbreak4all.sh -i examples/corpus/sgaw_kayin.txt -l sk -s "|"
# Out:
# |န|ဘၣ်|သံ|ကွၢ်|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |တၢ်|ဂ့ၢ်|ဝဲ|အံၤ|န|ဘၣ်|တဲ|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|ထံၣ်|လိာ်|သး|ဒီး|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|တၢ်|ဃု|ထၢ|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|စံၣ်|ညီၣ်|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဘၣ်|ကွၢ်|ဃု|တၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|တဲ|တ့ၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ဟ့ၣ်|တ့ၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ကိး|တ့ၢ်|မ|တၤ|န့ၣ်|လဲၣ်
# |န|ထံၣ်|တ့ၢ်|မ|တၤ|သ့ၣ်|န့ၣ်|လဲၣ်

# %%
# !bash bash/sylbreak4all.sh -i examples/corpus/rakhine.txt -l rk -s " "
# Out:
# မင်း ယင်း ချင့် ကို အ ခြား တစ် ခု နန့် မ ချိတ် ပါ လား ။
# ထို မ ချေ တစ် ယောက် လေ့ မ မှတ် မိ ပါ ယာ ။
# ယင်း ချင့် ကျွန် တော် ရို့ အ တွက် ခက် ခ ရေ ။
# မင်း ပြော ခ ရေ ပိုင် ကျွန် တော် ယှင်း ပြ ခ ရေ ။
# သူ့ ကို ထိန်း ဖို့ မင်း ရာ တတ် နိုင် ရေ ။
# ယင်း ချင့် ကို ငါ တက် နင်း မိ လား လာ ။
# ငါ စဉ်း စား ရေ ပိုင် စဉ်း စား ပါ ။
# အ တင်း ပြော ရ စွာ မုန်း ရေ ။
# ​ နောက် ဆုံး တစ် ကြိမ် သူ့ ကို ချစ် ပါ ရေ လို့ ပြော ခွင့် တောင် မ ရ ပါ ။
# နာ ဆာ မှ ဒုံး ပျံ စ တက် စွာ နန့် သူ မှတ် တမ်း ရွီး ခ ရေ ။

# %% [markdown]
# ## C++

# %%
# %pwd
# Out:
# '/mnt/disk1/ye/exp/sylbreak4all-0.9.0'

# %%
# %cd cpp
# Out:
# /mnt/disk1/ye/exp/sylbreak4all-0.9.0/cpp

# %%
# !ls
# Out:
# compile_cpp.sh	run_cpp.sh  sylbreak4all.cpp

# %%
# !./compile_cpp.sh

# %%
# !ls
# Out:
# compile_cpp.sh	run_cpp.sh  sylbreak4all  sylbreak4all.cpp

# %%
# !./run_cpp.sh -help
# Out:
# Unknown or incomplete argument: -help
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !./run_cpp.sh -i ../examples/corpus/shan.txt -l sh
# Out:
# |ယွင်ႈ|ၵုင်ႇ|ၵူၼ်း|ႁတ်း|ႁၢၼ်|ႁႃႉ
# |ဢၼ်|ၸႅတ်ႈ|တူၺ်း|သူ|ႁေႃႈ|ၵႃး|ၼႆႉ|တွပ်ႇ|ယဝ်ႉ|ယဝ်ႉ|ႁႃႉ
# |လွင်ႈ|ၶူင်|သၢင်ႈ|မႂ်း|ဢမ်ႇ|ႁိုင်|သင်|တေ|ဢွင်ႇ|မၢၼ်|ယဝ်ႉ
# |ဢၼ်|ၼၼ်ႉ|ပဵၼ်|လွင်ႈ|ၵိတ်ႇ|ၶွင်ႈ|သူ
# |တေ|ၵိၼ်|သေ|ဢၼ်|ဢၼ်|ႁႃႉ
# |ဢွမ်|မူင်း|ၵဝ်|ႁႃ|ဢမ်ႇ|ႁၼ်
# |ပဵၼ်|ၵူၼ်း|ဢၼ်|လဵၼ်ႈ|ၸိူင်း|ၶႅၼ်ႇ|တႄႉ|ယဝ်ႈ
# |ၵုပ်ႉ|ၵူႈ|သူ|ၼႆႉ|တႄႇ|ၽုၺ်ႇ|သႅင်ႇ|ၵိၼ်|ယမ်ႉ|ၼႆႉ|မႃး|တေႃႇ|မိူဝ်ႈ|လဵဝ်|ဢၼ်|ၽႅဝ်|မႃး|ၼႆႉ|ပဵၼ်|႙|႙|႙|ၵူႈ|ယဝ်ႉ
# |ၼင်ႈ|ႁွင်ႈ|တၢင်း|ၼႃႈ|ဢဝ်|ၼႄႈ
# |လႆႈ|ႁႅင်း|လီ|ၵႃႈ|ႁိုဝ်

# %%
# !./run_cpp.sh -i ../examples/corpus/mon.txt -l mo -s "/"
# Out:
# /၂/၀/မိ/ဏေတ်/ပၠန်/တှ်ေ/ဘာ/ရပ်/ဏောၚ်/။
# /ဗှ်ေ/ဟ/ယျ/တုဲ/မာန်/ဟာ/။
# /ယဝ်/ဗှ်ေ/ဟွံ/ပ/ယှုက်/အဲ/ရ/တှ်ေ/တုဲ/မာန်/ဏောၚ်/။
# /အဲ/ဟ/ယျ/ဗှ်ေ/တိၚ်/ဂီ/တာ/လေပ်/မံၚ်/။
# /လၟုဟ်/အဲဗ္တောန်/တိၚ်/မံၚ်/ဂီ/တာ/။
# /ပေါဲ/ဂီ/တ/ဂှ်/ဂိ/တု/ဂ/တ/မှ/ကၠောန်/ဏောၚ်/။
# /သွက်/အဲ/ဂွံ/အံၚ်/ဇၞး/ရာ/ဒ/နာ/ကဵု/ညိ/။
# /ခိုဟ်/ယျ/ဆက်/ဂ/စာန်/ညိ/ပၠန်/။
# /ဂ/လာန်/ဗှ်ေ/ပ/တိုန်/လဝ်/နူ/ဏေအ်ဗ္တံ/ဂှ်/ခိုဟ်/ကွေံ/ကွေံ/။
# /ၜိုတ်/အဲ/ကၠောန်/မာန်/အဲ/ဂ/စာန်/လဝ်/ရ/။

# %%
# !./run_cpp.sh -i ../examples/corpus/rakhine.txt -l rk -s " "
# Out:
# မင်း ယင်း ချင့် ကို အ ခြား တစ် ခု နန့် မ ချိတ် ပါ လား ။
# ထို မ ချေ တစ် ယောက် လေ့ မ မှတ် မိ ပါ ယာ ။
# ယင်း ချင့် ကျွန် တော် ရို့ အ တွက် ခက် ခ ရေ ။
# မင်း ပြော ခ ရေ ပိုင် ကျွန် တော် ယှင်း ပြ ခ ရေ ။
# သူ့ ကို ထိန်း ဖို့ မင်း ရာ တတ် နိုင် ရေ ။
# ယင်း ချင့် ကို ငါ တက် နင်း မိ လား လာ ။
# ငါ စဉ်း စား ရေ ပိုင် စဉ်း စား ပါ ။
# အ တင်း ပြော ရ စွာ မုန်း ရေ ။
# ​ နောက် ဆုံး တစ် ကြိမ် သူ့ ကို ချစ် ပါ ရေ လို့ ပြော ခွင့် တောင် မ ရ ပါ ။
# နာ ဆာ မှ ဒုံး ပျံ စ တက် စွာ နန့် သူ မှတ် တမ်း ရွီး ခ ရေ ။

# %% [markdown]
# ## R

# %%
# %cd /mnt/disk1/ye/exp/sylbreak4all-0.9.0
# Out:
# /mnt/disk1/ye/exp/sylbreak4all-0.9.0

# %%
# !ls
# Out:
# bash  examples	   julia    php     README.md  SylBreak4All_Demo.ipynb
# cpp   java	   LICENSE  python  ruby       VERSION
# docs  java_script  perl     R	    scripts

# %%
# !Rscript --help
# Out:
# Usage: Rscript [options] file [args]
#    or: Rscript [options] -e expr [-e expr2 ...] [args]
# A binary front-end to R, for use in scripting applications.
#
# Options:
#   --help              Print usage and exit
#   --version           Print version and exit
#   --verbose           Print information on progress
#   --default-packages=LIST  Attach these packages on startup;
#                         a comma-separated LIST of package names, or 'NULL'
# and options to R (in addition to --no-echo --no-restore), for example:
#   --save              Do save workspace at the end of the session
#   --no-environ        Don't read the site and user environment files
#   --no-site-file      Don't read the site-wide Rprofile
#   --no-init-file      Don't read the user R profile
#   --restore           Do restore previously saved objects at startup
#   --vanilla           Combine --no-save, --no-restore, --no-site-file,
#                         --no-init-file and --no-environ
#
# ...

# %%
# !Rscript R/sylbreak4all.R --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !Rscript R/sylbreak4all.R \
    -i examples/corpus/mon.txt \
    -l mo
# Out:
# |၂|၀|မိ|ဏေတ်|ပၠန်|တှ်ေ|ဘာ|ရပ်|ဏောၚ်|။
# |ဗှ်ေ|ဟ|ယျ|တုဲ|မာန်|ဟာ|။
# |ယဝ်|ဗှ်ေ|ဟွံ|ပ|ယှုက်|အဲ|ရ|တှ်ေ|တုဲ|မာန်|ဏောၚ်|။
# |အဲ|ဟ|ယျ|ဗှ်ေ|တိၚ်|ဂီ|တာ|လေပ်|မံၚ်|။
# |လၟုဟ်|အဲဗ္တောန်|တိၚ်|မံၚ်|ဂီ|တာ|။
# |ပေါဲ|ဂီ|တ|ဂှ်|ဂိ|တု|ဂ|တ|မှ|ကၠောန်|ဏောၚ်|။
# |သွက်|အဲ|ဂွံ|အံၚ်|ဇၞး|ရာ|ဒ|နာ|ကဵု|ညိ|။
# |ခိုဟ်|ယျ|ဆက်|ဂ|စာန်|ညိ|ပၠန်|။
# |ဂ|လာန်|ဗှ်ေ|ပ|တိုန်|လဝ်|နူ|ဏေအ်ဗ္တံ|ဂှ်|ခိုဟ်|ကွေံ|ကွေံ|။
# |ၜိုတ်|အဲ|ကၠောန်|မာန်|အဲ|ဂ|စာန်|လဝ်|ရ|။

# %%
# !Rscript R/sylbreak4all.R \
    -i examples/corpus/shan.txt \
    -l sh
# Out:
# |ယွင်ႈ|ၵုင်ႇ|ၵူၼ်း|ႁတ်း|ႁၢၼ်|ႁႃႉ
# |ဢၼ်|ၸႅတ်ႈ|တူၺ်း|သူ|ႁေႃႈ|ၵႃး|ၼႆႉ|တွပ်ႇ|ယဝ်ႉ|ယဝ်ႉ|ႁႃႉ
# |လွင်ႈ|ၶူင်|သၢင်ႈ|မႂ်း|ဢမ်ႇ|ႁိုင်|သင်|တေ|ဢွင်ႇ|မၢၼ်|ယဝ်ႉ
# |ဢၼ်|ၼၼ်ႉ|ပဵၼ်|လွင်ႈ|ၵိတ်ႇ|ၶွင်ႈ|သူ
# |တေ|ၵိၼ်|သေ|ဢၼ်|ဢၼ်|ႁႃႉ
# |ဢွမ်|မူင်း|ၵဝ်|ႁႃ|ဢမ်ႇ|ႁၼ်
# |ပဵၼ်|ၵူၼ်း|ဢၼ်|လဵၼ်ႈ|ၸိူင်း|ၶႅၼ်ႇ|တႄႉ|ယဝ်ႈ
# |ၵုပ်ႉ|ၵူႈ|သူ|ၼႆႉ|တႄႇ|ၽုၺ်ႇ|သႅင်ႇ|ၵိၼ်|ယမ်ႉ|ၼႆႉ|မႃး|တေႃႇ|မိူဝ်ႈ|လဵဝ်|ဢၼ်|ၽႅဝ်|မႃး|ၼႆႉ|ပဵၼ်|႙|႙|႙|ၵူႈ|ယဝ်ႉ
# |ၼင်ႈ|ႁွင်ႈ|တၢင်း|ၼႃႈ|ဢဝ်|ၼႄႈ
# |လႆႈ|ႁႅင်း|လီ|ၵႃႈ|ႁိုဝ်

# %%
# !Rscript R/sylbreak4all.R \
    -i examples/corpus/pao.txt \
    -l po
# Out:
# |လို|မူႏ|ပေႏ|မာꩻ|တ|မုဲင်ꩻ|ဟောင်း
# |ဝွေꩻ|သီး|အီး|ကွီႏ|သ|ညင်ꩻ|နာꩻ|တ|မွေး|တဝ်း
# |နီ|တ|ယူႏ|လ|တဝ်း|ခင်ႏ|လမ်း|နဝ်ꩻ
# |နာꩻ|ပါꩻ|မုဲင်ꩻ|မန်|နေ|ဂျာ|ဟောင်း
# |ဝွေꩻ|မူႏ|ခြောဝ်|ငဝ်း
# |နာꩻ|နမ်း|တွမ်ႏ|နာꩻ|နမ်း|ယွုမ်း|အံႏ|မုꩻ|မဉ်|အဝ်ႏ|တဲ့|ကျိုꩻ|စာꩻ|စံ|ဟုဲင်း
# |ချာ|နေ|နမ်း|မဉ်|ဟောင်း
# |ဝွေꩻ|မူႏ|တွမ်ႏ|ဝွေꩻ|ထေင်|ညင်|ချာ|ငါꩻ|ဝင်ꩻ|ဟောင်း
# |နာꩻ|နဝ်ꩻ|လို|လွစ်|ဟောင်း
# |အ|ရီး|သွတ်|တ|ဗာႏ|အ|နေႏ|ဝွေꩻ|မူႏ|အဝ်ႏ|လိုႏ|ဖျင်ꩻ|ဆင်ꩻ|ဒဲဉ်ꩻ|ရဝ်ꩻ|တာႏ

# %% [markdown]
# ## Julia

# %%
# !julia --version
# Out:
# julia version 1.8.1

# %%
# %pwd
# Out:
# '/mnt/disk1/ye/exp/sylbreak4all-0.9.0'

# %%
# !julia julia/sylbreak4all.jl --help
# Out:
# Syllable Breaker Tool
# Version: 0.9.0
#
# Supported Languages:
#     bm  - Burmese
#     bk  - Beik
#     dw  - Dawei
#     rk  - Rakhine
#     mo  - Mon
#     po  - PaO
#     sh  - Shan
#     sk  - Sgaw Kayin
#     pk  - Pwo Kayin
#
# Usage: sylbreak4all [-i filename] [-l language] [-s separator] [-p]
#     -i | --input-file   Input file name (default: STDIN)
#     -s | --separator    Separator (default: '|')
#     -l | --language     Language (default: bm for Burmese)
#     -p | --print        Print input alongside the output (default: 0)
#     -h | --help         Show this help

# %%
# !./julia/run_julia.sh \
    -i examples/corpus/shan.txt \
    -l sh
# Out:
# |ယွင်ႈ|ၵုင်ႇ|ၵူၼ်း|ႁတ်း|ႁၢၼ်|ႁႃႉ
# |ဢၼ်|ၸႅတ်ႈ|တူၺ်း|သူ|ႁေႃႈ|ၵႃး|ၼႆႉ|တွပ်ႇ|ယဝ်ႉ|ယဝ်ႉ|ႁႃႉ
# |လွင်ႈ|ၶူင်|သၢင်ႈ|မႂ်း|ဢမ်ႇ|ႁိုင်|သင်|တေ|ဢွင်ႇ|မၢၼ်|ယဝ်ႉ
# |ဢၼ်|ၼၼ်ႉ|ပဵၼ်|လွင်ႈ|ၵိတ်ႇ|ၶွင်ႈ|သူ
# |တေ|ၵိၼ်|သေ|ဢၼ်|ဢၼ်|ႁႃႉ
# |ဢွမ်|မူင်း|ၵဝ်|ႁႃ|ဢမ်ႇ|ႁၼ်
# |ပဵၼ်|ၵူၼ်း|ဢၼ်|လဵၼ်ႈ|ၸိူင်း|ၶႅၼ်ႇ|တႄႉ|ယဝ်ႈ
# |ၵုပ်ႉ|ၵူႈ|သူ|ၼႆႉ|တႄႇ|ၽုၺ်ႇ|သႅင်ႇ|ၵိၼ်|ယမ်ႉ|ၼႆႉ|မႃး|တေႃႇ|မိူဝ်ႈ|လဵဝ်|ဢၼ်|ၽႅဝ်|မႃး|ၼႆႉ|ပဵၼ်|႙|႙|႙|ၵူႈ|ယဝ်ႉ
# |ၼင်ႈ|ႁွင်ႈ|တၢင်း|ၼႃႈ|ဢဝ်|ၼႄႈ
# |လႆႈ|ႁႅင်း|လီ|ၵႃႈ|ႁိုဝ်

# %%
# !./julia/run_julia.sh \
    -i examples/corpus/bamar_burmese.txt
# Out:
# |က|ခ|ဂ|ဃ|င|၀|၁|၂|၃|၄|၅|၆|၇|၈|၉
# |နေ|ကောင်း|လား|။
# |ကျန်း|မာ|တယ်|၊|ဒါ|ပေ|မဲ့|အ|လုပ်|များ|တယ်|။
# |မင်္ဂ|လာ|ပါ|ဆ|ရာ|မ|။
# |တက္က|သိုလ်|အ|သွား|အ|ပြန်|ကို|သင်္ဘော|စီး|ပြီး|သွား|ရ|တယ်|။
# |ပုပ္ပါး|တောင်|ကို|ထပ်|တက်|ချင်|သေး|တယ်|။
# |ကျောင်း|သား|ကျောင်း|သွား|ပါ|။
# |က|လေး|က|အိမ်|မှာ|ပါ
# |ကျောင်း|သား|ကျောင်း|သူ|ကျောင်း|မှာ
# |ပါ|ပါ|သ|မီး|ကို|လွမ်း|နေ|တယ်|။

# %%
# !./julia/run_julia.sh \
    -i examples/corpus/rakhine.txt \
    -l rk -s "|"
# Out:
# |မင်း|ယင်း|ချင့်|ကို|အ|ခြား|တစ်|ခု|နန့်|မ|ချိတ်|ပါ|လား|။
# |ထို|မ|ချေ|တစ်|ယောက်|လေ့|မ|မှတ်|မိ|ပါ|ယာ|။
# |ယင်း|ချင့်|ကျွန်|တော်|ရို့|အ|တွက်|ခက်|ခ|ရေ|။
# |မင်း|ပြော|ခ|ရေ|ပိုင်|ကျွန်|တော်|ယှင်း|ပြ|ခ|ရေ|။
# |သူ့|ကို|ထိန်း|ဖို့|မင်း|ရာ|တတ်|နိုင်|ရေ|။
# |ယင်း|ချင့်|ကို|ငါ|တက်|နင်း|မိ|လား|လာ|။
# |ငါ|စဉ်း|စား|ရေ|ပိုင်|စဉ်း|စား|ပါ|။
# |အ|တင်း|ပြော|ရ|စွာ|မုန်း|ရေ|။
# ​|နောက်|ဆုံး|တစ်|ကြိမ်|သူ့|ကို|ချစ်|ပါ|ရေ|လို့|ပြော|ခွင့်|တောင်|မ|ရ|ပါ|။
# |နာ|ဆာ|မှ|ဒုံး|ပျံ|စ|တက်|စွာ|နန့်|သူ|မှတ်|တမ်း|ရွီး|ခ|ရေ|။

# %% [markdown]
# ## Check results/ Folder

# %%
# !head ./examples/results/*
# Out:
# ==> ./examples/results/bamar_burmese.txt <==
# |က|ခ|ဂ|ဃ|င|၀|၁|၂|၃|၄|၅|၆|၇|၈|၉
# |နေ|ကောင်း|လား|။
# |ကျန်း|မာ|တယ်|၊|ဒါ|ပေ|မဲ့|အ|လုပ်|များ|တယ်|။
# |မင်္ဂ|လာ|ပါ|ဆ|ရာ|မ|။
# |တက္က|သိုလ်|အ|သွား|အ|ပြန်|ကို|သင်္ဘော|စီး|ပြီး|သွား|ရ|တယ်|။
# |ပုပ္ပါး|တောင်|ကို|ထပ်|တက်|ချင်|သေး|တယ်|။
# |ကျောင်း|သား|ကျောင်း|သွား|ပါ|။
# |က|လေး|က|အိမ်|မှာ|ပါ
# |ကျောင်း|သား|ကျောင်း|သူ|ကျောင်း|မှာ
# |ပါ|ပါ|သ|မီး|ကို|လွမ်း|နေ|တယ်|။
#
# ==> ./examples/results/beik.txt <==
# |နင်|ဘာ|စီ|စဉ်|နေ|ရယ်|ဆို|တာ|ငါ့|ဝို|ပြော|သင့်|ပေါ့|လန်း|။
# |သူ|လို့|စာ|အုပ်|သုံး|ထောင်|ကျော်|ရောင်း|ပီး|ဟော|ဘီ|။
# |ငယ်|ငယ်|တည်း|က|မင်း|သား|လုပ်|ဝို့|ဝါ|သ|နာ|ပါ|စ|။
# |သူ|တစ်|ချိန်|လုံး|လုပ်|နေ|ဇာ|ဂ|ညဉ်း|ပဲ့|ညည်း|နေ|ဇာ|။
# |ဒယ်|ကောင်|မ|ငယ်|နင့်|ဝို|ဂ|ရု|စိုက်|ရယ်|လား|။
# |ဘ|ဇာ|လောက်|မြင့်|မြတ်|ရိ|။
# |နင်|ဒယ်|မှာ|အ|လုပ်|လုပ်|ဝယ်|။
# |ဒယ်|ကောင်|မ|ငယ်|ဟ|မင်း|ဟက်|သ|ဘော|တူ|မှာ|မ|ဟုတ်|ဝ|။
# |နင့်|ရဲ့|သွား|နှစ်|ချောင်း|ကို|နုတ်|ပစ်|ရ|မရ်|။
# |သူ့|ဆီ|ကို|နင်|ဖုန်း|ဆက်|မယ်|မ|ဟုတ်|ဝ|လား|။
#
# ==> ./examples/results/dawei.txt <==
# ...
